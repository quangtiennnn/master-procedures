# %%
# %%capture
import csv
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
import pandas as pd

from scripts.dataframe_selection import *
from scripts.tools import *

# %% [markdown]
# # Importing data

# %%
df = pd.read_csv('database/hotel_review_en_vi_with_distance.csv')
# Out:
# C:\Users\darkn\AppData\Local\Temp\ipykernel_15788\1053113034.py:1: DtypeWarning: Columns (16,17,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('database/hotel_review_en_vi_with_distance.csv')

# %%
# df

# %% [markdown]
# # Preprocessing

# %% [markdown]
# We suggest on doing on big dataframe first since it is better to re-use than training again.
#
# However, we still simulate two type of preprocessing on `type = "sample"` and `type = "population"`

# %% [markdown]
# ## Sample

# %%
sample = df.sample(n = 30)

# %% [markdown]
# We set `type = 'sample'` as default setting

# %%
def preprocess(df: pd.DataFrame,type = 'sample'):
    print("Preprocesing...")
    if type == 'sample':
        df['processed_comment'] = df['comment'].astype(str).apply(normalization)
        df['processed_comment'] = df.apply(lambda row: word_segmentation(row['processed_comment'], row['language']), axis=1)
        return df
    elif type == 'population':
        file_path = 'database/processed_hotel_reviews.csv'
        if os.path.isfile(file_path):
            df = pd.read_csv(file_path, index_col=0)
        else:    
            df['processed_comment'] = df['comment'].astype(str).apply(normalization)
            df['processed_comment'] = df.apply(lambda row: word_segmentation(row['processed_comment'], row['language']), axis=1)
            df.to_csv(file_path,index= True,encoding = 'utf-8-sig')
        return df

# %%
# %%time
processed_df = preprocess(sample,type = 'sample')
processed_df[['comment','processed_comment']]
# Out:
# Preprocesing...
# CPU times: total: 109 ms
# Wall time: 279 ms
#                                                   comment  \
# 95321   Wonderful, professional staff that speak Engli...
# 22495   We really enjoyed beautiful and calm atmospher...
# 52143   The pictures look a million times better than ...
# 103876  Pool was nice. Close to beach. Staff were a bi...
# 57965   Excellent location, spacious rooms with nice v...
# 80281              May come from door opened to fresh air
# 50869   Staff were prompt, location was good. Room was...
# 79987   Very nice hotel. Friendly staff, very accommod...
# 109911    Very convenient location and clean and friendly
# 86700   Do covid 19 nên Little Beach Hội An chưa mở cử...
# 73721   Location is very convenient and close to the m...
# 120979                                       phòng hơi bé
# 35198   Too expensive for that city. Unfriendly staff ...
# 31842   clean cheap friendly nice hotel, near and frie...
# 76050   Hotel staff were exceptionally polite and frie...
# 78921   Hotel sạch đẹp thoáng mát nhiều cây, phòng ở o...
# 91764   I was forced to change the room. I wanted to b...
# 12910   Khách sạn hơi cũ nhưng cũng sạch sẽ, lễ tân vu...
# 111217  Very clean, close to other places, staffs are ...
# 96465   Khách sạn khá ổn so với tầm giá, với mức giá n...
# 93543   its so clean. but it still little far from mar...
# 6921    12 days staying in Somerset Chancellor Court S...
# 55363   Phong kha rong rai, sach se, tien nghi day du,...
# 121134  You won’t regret for getting your stay here. M...
# 205     When I checked out, they refused to issue a ho...
# 49389   The hotel is centrally located, just a few ste...
# 62070   Greatly enjoyed our stay. Everyone was friendl...
# 78158   Mình và gia đình rất hài lòng về dịch vụ và lễ...
# 24898   Nice clean room, although slightly dark for my...
# 52363   Book for 4 people but amenities given for 2. N...
#
#                                         processed_comment
# 95321   wonderful professional staff that speak englis...
# 22495   we really enjoyed beautiful and calm atmospher...
# 52143   the pictures look a million times better than ...
# 103876  pool was nice close to beach staff were a bit ...
# 57965   excellent location spacious rooms with nice vi...
# 80281              may come from door opened to fresh air
# 50869   staff were prompt location was good room was c...
# 79987   very nice hotel friendly staff very accommodat...
# 109911    very convenient location and clean and friendly
# 86700   do covid 19 nên little beach hội an chưa mở_cử...
# 73721   location is very convenient and close to the m...
# 120979                                       phòng hơi bé
# 35198   too expensive for that city unfriendly staff r...
# 31842   clean cheap friendly nice hotel near and frien...
# 76050   hotel staff were exceptionally polite and frie...
# 78921   hotel sạch đẹp thoáng mát nhiều cây phòng ở ok...
# 91764   i was forced to change the room i wanted to bo...
# 12910   khách_sạn hơi cũ nhưng cũng sạch sẽ lễ_tân vui_vẻ
# 111217  very clean close to other places staffs are fr...
# 96465   khách_sạn khá ổn so với tầm giá với mức giá nà...
# 93543   its so clean but it still little far from mark...
# 6921    12 days staying in somerset chancellor court s...
# 55363   phong kha rong_rai sach se tien nghi day du co...
# 121134  you wo n’t regret for getting your stay here m...
# 205     when i checked out they refused to issue a hot...
# 49389   the hotel is centrally located just a few step...
# 62070   greatly enjoyed our stay everyone was friendly...
# 78158   mình và gia_đình rất hài_lòng về dịch_vụ và lễ...
# 24898   nice clean room although slightly dark for my ...
# 52363   book for 4 people but amenities given for 2 ne...

# %% [markdown]
# We storing the **index** also too use that again if needed

# %%
def embedding(docs,encoder,type='sample'):
    print("Embedding...")
    if type == 'sample':
        corpus_embeddings = encoder.encode(docs, show_progress_bar=False)
        return corpus_embeddings
    elif type == 'population':
        file_path = f'database/corpus_embeddings.npy'
        try:
            # Load pre-computed embeddings if they exist
            corpus_embeddings = np.load(file_path)
        except FileNotFoundError:
            # Compute embeddings if they do not exist
            corpus_embeddings = encoder.encode(docs, show_progress_bar=True)
            # Save embeddings for future use
            np.save(file_path, corpus_embeddings)
        return corpus_embeddings

# %% [markdown]
# We use this encoder since [SBERT](https://www.sbert.net/docs/sentence_transformer/pretrained_models.html) shows the performance of various SBERT model. Moreover, this model are handle good Vietnamese because I was manualy check it by hand.

# %%
# %%capture
encoder = SentenceTransformer('sentence-transformers/paraphrase-multilingual-mpnet-base-v2')

# %%
# %%time
docs = processed_df.processed_comment.values
corpus_embeddings = embedding(docs,encoder,type='sample')
# Out:
# Embedding...
# CPU times: total: 4.23 s
# Wall time: 2.88 s

# %%
corpus_embeddings,corpus_embeddings.shape
# Out:
# (array([[-0.11418362,  0.07794645, -0.00995048, ...,  0.19378589,
#           0.19440794, -0.05447968],
#         [ 0.13635494, -0.07272205, -0.0089131 , ..., -0.02221631,
#          -0.00774254,  0.0802676 ],
#         [ 0.0761268 ,  0.24591573, -0.00789728, ..., -0.0491119 ,
#          -0.08772048,  0.09289229],
#         ...,
#         [ 0.01215874,  0.07802645, -0.02126045, ...,  0.08571438,
#           0.01309518, -0.01906305],
#         [-0.0317916 , -0.02985834, -0.00224115, ...,  0.00880288,
#          -0.00788458,  0.11723903],
#         [ 0.0534906 , -0.15266998, -0.00647984, ..., -0.0505357 ,
#          -0.1616588 ,  0.01065221]], dtype=float32),
#  (30, 768))

# %% [markdown]
# # Population

# %% [markdown]
# Since we need to extract model again and again, the re-use of corpus embedding are needed.

# %%
df.shape
# Out:
# (124603, 30)

# %%
# %%time
processed_df = preprocess(df,type = 'population')
processed_df[['comment','processed_comment']]
# Out:
# Preprocesing...
# CPU times: total: 1.11 s
# Wall time: 1.79 s
# C:\Users\darkn\AppData\Local\Temp\ipykernel_15788\2682743059.py:10: DtypeWarning: Columns (17,18,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, index_col=0)
#                                                   comment  \
# 0       A tourist class hotel with very basic amenitie...
# 1       The hotel rooms etc are good but very very sti...
# 2              Really enjoy my stay here. Will stay again
# 3                                               excellent
# 4        Great and decent place for sightseeing and tours
# ...                                                   ...
# 124598  Phòng ốc sạch sẽ, tiện nghi, nhân viên thân th...
# 124599     Sạch sẽ, tiện nghi sẽ quay lại, ko có j để chê
# 124600      Không gian sạch sẽ, thoải mái, giá cả phù hợp
# 124601              Sạch sẽ , thơm , sẽ trải nghiệm tiêdp
# 124602     Sạch sẽ , các b tiêpd tân dễ gần và nhiệt tình
#
#                                         processed_comment
# 0       a tourist class hotel with very basic amenitie...
# 1       the hotel rooms etc are good but very very sti...
# 2               really enjoy my stay here will stay again
# 3                                               excellent
# 4        great and decent place for sightseeing and tours
# ...                                                   ...
# 124598  phòng_ốc sạch_sẽ tiện_nghi nhân_viên thân_thiệ...
# 124599       sạch_sẽ tiện_nghi sẽ quay lại ko có j để chê
# 124600        không_gian sạch_sẽ thoải_mái giá_cả phù_hợp
# 124601                  sạch_sẽ thơm sẽ trải nghiệm tiêdp
# 124602       sạch_sẽ các b tiêpd tân dễ gần và nhiệt_tình
#
# [124603 rows x 2 columns]

# %%
# %%time
docs = processed_df.processed_comment.values
corpus_embeddings = embedding(docs,encoder,type='population')
# Out:
# Embedding...
# CPU times: total: 78.1 ms
# Wall time: 451 ms

# %%
corpus_embeddings.shape
# Out:
# (124603, 768)

# %% [markdown]
# # Process

# %%
sample = df.sample(n = 2000)
sample.head(5)
# Out:
#         hotel_id                         hotel_name  \
# 115379   9412242                         Camy Hotel
# 117333  10889436                      BLESSED Hotel
# 94627    3849840                       MAY BUNGALOW
# 82335    1624612  Muong Thanh Luxury Phu Quoc Hotel
# 18475     281592                   Villa Pink House
#
#                                              addressline1              city  \
# 115379                                 236 Phan Chu Trinh          Vung Tau
# 117333  46-48 Hung Gia 1 st, Tan Phong ward, District ...  Ho Chi Minh City
# 94627                             246/2 nguyen dinh chieu        Phan Thiet
# 82335   Group 3, Duong Bao Hamlet, Duong To Commune, P...   Phu Quoc Island
# 18475   67/6 (Old Number 7/8) Hai Thuong Street, Ward ...             Dalat
#
#                   state  numberrooms  yearopened  yearrenovated  \
# 115379  Ba Ria Vung Tau         15.0      2018.0            NaN
# 117333      Ho Chi Minh         18.0      2020.0         2020.0
# 94627        Binh Thuan         12.0      2018.0         2021.0
# 82335        Kien Giang        276.0      2016.0         2016.0
# 18475          Lam Dong         21.0      2001.0         2019.0
#
#         number_of_reviews  rating_average  ...  accommodationtype2  \
# 115379                253             9.0  ...                 NaN
# 117333                612             9.0  ...                 NaN
# 94627                 817             9.3  ...                 NaN
# 82335                1050             8.0  ...                 NaN
# 18475                 641             7.7  ...                 NaN
#
#        accommodationtype3 accommodationtype4 language reviewer_continent  \
# 115379                NaN                NaN       vi               Asia
# 117333                NaN                NaN       en               Asia
# 94627                 NaN                NaN       en             Europe
# 82335                 NaN                NaN       en               Asia
# 18475                 NaN                NaN       en             Europe
#
#          longitude   latitude              hotel_coordinate  dis2coast  \
# 115379  107.083620  10.330615   POINT (107.08362 10.330615)      0.383
# 117333  106.708514  10.733383  POINT (106.708514 10.733383)     40.738
# 94627   108.247068  10.953706  POINT (108.247068 10.953706)      0.094
# 82335   103.979855  10.132683  POINT (103.979855 10.132683)      0.454
# 18475   108.430097  11.944060   POINT (108.430097 11.94406)     73.526
#
#                                    nearest_coordinate
# 115379  POINT (11920843.302334243 1148465.2649964693)
# 117333  POINT (11907922.454514029 1165509.8719933222)
# 94627    POINT (12049988.609741127 1218651.862620137)
# 82335   POINT (11574539.250734488 1126288.9418734254)
# 18475     POINT (12134860.5102322 1295168.6063270567)
#
# [5 rows x 30 columns]

# %%
selection = Selection(sample)

# %%
selection.language.value_counts()
# Out:
# language
# en    38
# vi    12
# Name: count, dtype: int64

# %%
filtered_hotel = selection.filtering(
    extracting = 'review',
#     province=['Da Nang'],
#     star_rating=[3],
#     region=['Central Vietnam'],
#     dis2coast=[0, 0.5],
#     seaside=0
)
filtered_hotel
# Out:
#         hotel_id  star_rating                    coordinate          province  \
# 26680     294583          4.0  POINT (106.697094 10.773663)   TP. Ho Chi Minh
# 57281     961865          3.0  POINT (105.853913 21.032068)            Ha Noi
# 64161    1195442          3.0  POINT (108.434546 11.941766)          Lam Dong
# 68969    1206496          3.0  POINT (108.329178 15.886979)         Quang Nam
# 107143   6494378          3.0  POINT (109.200022 12.226268)         Khanh Hoa
# 51552     861998          3.0  POINT (106.692631 10.768471)   TP. Ho Chi Minh
# 11180     186800          2.0  POINT (108.326616 15.880324)         Quang Nam
# 110729   6998893          3.0  POINT (105.847697 21.032573)            Ha Noi
# 27450     294583          4.0  POINT (106.697094 10.773663)   TP. Ho Chi Minh
# 35975     400379          2.0  POINT (108.231065 16.066114)           Da Nang
# 104535   6253027          3.0  POINT (106.704633 10.776724)   TP. Ho Chi Minh
# 10109     173625          3.0  POINT (106.689501 10.771015)   TP. Ho Chi Minh
# 80840    1623811          3.0    POINT (106.6958 10.771914)   TP. Ho Chi Minh
# 21682     286608          5.0   POINT (106.68305 10.764677)   TP. Ho Chi Minh
# 87350    1984702          2.0  POINT (103.959112 10.218325)        Kien Giang
# 18343     281497          5.0   POINT (108.227005 16.04837)           Da Nang
# 34544     398910          2.0  POINT (106.692181 10.766696)   TP. Ho Chi Minh
# 52086     861998          3.0  POINT (106.692631 10.768471)   TP. Ho Chi Minh
# 84170    1637664          3.0   POINT (105.848226 21.03497)            Ha Noi
# 114159   8820021          0.0  POINT (106.696456 10.760261)   TP. Ho Chi Minh
# 62812    1193672          4.0   POINT (105.85487 21.031366)            Ha Noi
# 55890     923927          0.0  POINT (103.842929 22.332829)           Lao Cai
# 104285   6177083          3.0    POINT (108.431412 11.9426)          Lam Dong
# 118611  10960213          2.0  POINT (105.851204 21.034218)            Ha Noi
# 8350       81748          4.0  POINT (105.846107 21.039601)            Ha Noi
# 26257     294583          4.0  POINT (106.697094 10.773663)   TP. Ho Chi Minh
# 99366    5663891          5.0   POINT (107.59446 16.463878)  Thua Thien - Hue
# 6941       65491          5.0  POINT (106.699608 10.784176)   TP. Ho Chi Minh
# 82818    1624707          4.0  POINT (109.191193 12.239019)         Khanh Hoa
# 3612       10990          3.0  POINT (106.706252 10.773774)   TP. Ho Chi Minh
# 99334    5663891          5.0   POINT (107.59446 16.463878)  Thua Thien - Hue
# 35173     399036          1.0  POINT (104.484253 10.379956)        Kien Giang
# 106544   6426066          0.0  POINT (105.931329 20.217052)         Ninh Binh
# 71483    1266368          3.0  POINT (105.848126 21.029371)            Ha Noi
# 12636     237273          4.0  POINT (107.583028 16.457771)  Thua Thien - Hue
# 93174    2849135          3.0   POINT (105.85572 21.031271)            Ha Noi
# 18167     281497          5.0   POINT (108.227005 16.04837)           Da Nang
# 120404  12166451          3.0   POINT (108.33087 15.889771)         Quang Nam
# 91846    2616748          3.0  POINT (108.243706 16.065948)           Da Nang
# 5565       52067          0.0  POINT (105.784798 10.031013)           Can Tho
# 104808   6365766          2.0  POINT (106.719244 10.823143)   TP. Ho Chi Minh
# 80241    1620556          2.0  POINT (108.243243 16.068177)           Da Nang
# 97863    5480201          2.0  POINT (105.937706 20.216916)         Ninh Binh
# 41611     535511          3.0  POINT (105.849087 21.035781)            Ha Noi
# 82698    1624661          3.0  POINT (106.666959 10.811497)   TP. Ho Chi Minh
# 104489   6253027          3.0  POINT (106.704633 10.776724)   TP. Ho Chi Minh
# 20827     285738          3.0  POINT (105.847041 21.036504)            Ha Noi
# 13482     237764          2.0  POINT (106.696486 10.771836)   TP. Ho Chi Minh
# 111895   7125810          4.0  POINT (106.697114 10.773823)   TP. Ho Chi Minh
# 88181    2100642          0.0  POINT (106.709862 10.790225)   TP. Ho Chi Minh
#
#                  region  dis2coast  seaside  \
# 26680           unknown     44.875        0
# 57281     North Vietnam     97.641        0
# 64161   Central Vietnam     72.967        0
# 68969   Central Vietnam      3.346        0
# 107143  Central Vietnam      0.041        1
# 51552           unknown     44.789        0
# 11180   Central Vietnam      4.139        0
# 110729    North Vietnam     98.243        0
# 27450           unknown     44.875        0
# 35975   Central Vietnam      0.340        1
# 104535          unknown     44.567        0
# 10109           unknown     45.237        0
# 80840           unknown     44.829        0
# 21682           unknown     45.230        0
# 87350     South Vietnam      0.366        1
# 18343   Central Vietnam      0.135        1
# 34544           unknown     44.680        0
# 52086           unknown     44.789        0
# 84170     North Vietnam     98.357        0
# 114159          unknown     43.828        0
# 62812     North Vietnam     97.506        0
# 55890     North Vietnam    368.906        0
# 104285  Central Vietnam     73.318        0
# 118611    North Vietnam     98.034        0
# 8350      North Vietnam     98.865        0
# 26257           unknown     44.875        0
# 99366   Central Vietnam     12.710        0
# 6941            unknown     45.566        0
# 82818   Central Vietnam      0.486        1
# 3612            unknown     44.199        0
# 99334   Central Vietnam     12.710        0
# 35173     South Vietnam      0.131        1
# 106544    North Vietnam     29.890        0
# 71483     North Vietnam     97.987        0
# 12636   Central Vietnam     13.933        0
# 93174     North Vietnam     97.422        0
# 18167   Central Vietnam      0.135        1
# 120404  Central Vietnam      2.974        0
# 91846   Central Vietnam      0.137        1
# 5565      South Vietnam     75.950        0
# 104808          unknown     47.623        0
# 80241   Central Vietnam      0.171        1
# 97863     North Vietnam     29.706        0
# 41611     North Vietnam     98.334        0
# 82698           unknown     50.282        0
# 104489          unknown     44.567        0
# 20827     North Vietnam     98.569        0
# 13482           unknown     44.770        0
# 111895          unknown     44.887        0
# 88181           unknown     45.339        0
#
#                                                   comment  sentiment national  \
# 26680   Hotel is good, considering the price and locat...          1       KR
# 57281              only one comment is breakfast quality.          1       TH
# 64161   sạch sẽ, nhân viên lễ phép, phòng đồ đạc ok, c...          1       VN
# 68969   Toilet gets very wet when shower is done, as t...          1       MY
# 107143  Difficult to find the place. No view as showed...          0       VN
# 51552   The location was great. Check out the egg coff...          1       IN
# 11180   This hotel need to be deep clean, maintain bec...         -1       FR
# 110729  A massive shout out to the staff at this hotel...          1       NZ
# 27450                                            too poor         -1       US
# 35975   My wife and I strongly suspect that the hotel ...          1       US
# 104535                                               Good          1       KR
# 10109   Not a bad place but when we stayed there they ...          1       TW
# 80840                        Phòng mới đẹp, giá cả hợp lý          1       VN
# 21682                                  Nice dinner buffet          1       KR
# 87350   Khach san ơ ngay dau cong cho dem, cach Dinh C...          1       VN
# 18343   Very good customer service. A staff recommende...          1       SG
# 34544   Love this place that’s why we stayed for anoth...          1       PH
# 52086   Nhân viên nhiệt tình. Phòng hơi cũ, nhà WC có ...          1       VN
# 84170   The best hotel we have stayed in Vietnam. We w...          1       VN
# 114159                                 good place to stay          1       VN
# 62812   As in other hotels in old quarter it is small ...          1       IN
# 55890   She let me know many tips for sapa trip. Also ...          1       VN
# 104285  Mình có lưu trú tại khách sạn 2 đêm (từ ngày 9...          1       VN
# 118611  Phòng diện tích nhỏ nên giường chỉ khoảng 1,5m...          1       VN
# 8350    Henry greeted us and prepared our room. He is ...          1       US
# 26257                       Overall still is a nice stay.          1       SG
# 99366   It was enough that the view from our room was ...          1       US
# 6941    Great Place to stay. more value for money than...          1       CA
# 82818   Nice room with city view, good service and ful...          1       TH
# 3612    The Hotel was very clean, the morning breakfas...          1       US
# 99334   Cả gia đình ở hotel này thì tuyệt; dịch vụ san...          1       VN
# 35173   The hotel is right in front of the market and ...          0       DE
# 106544  Phục vụ thân thiện, giá cả phải chăng. Gần Thu...          1       VN
# 71483   Good and affordable place to stay while in Han...          1       JP
# 12636   Excellent hotel, large clean room, good food a...          1       GB
# 93174   Hotel was located 5-10 minutes away from the p...          1       SG
# 18167   Thank you for upgrading our room. And I think ...          0       KR
# 120404        Great view, greate location, friendly staff          1       VN
# 91846                           Good place and good price          1       VN
# 5565                      Máy lạnh yếu không đủ lạnh...?!          1       VN
# 104808  Đồ cũ, ko có điều hoà nhé mn, đồ cũ kĩ luôn. C...         -1       VN
# 80241                  Đáng đồng tiền, chị chủ thân thiện          1       VN
# 97863   This is a good option if you're looking for a ...          1       FR
# 41611   They give us welcome drink and snack when we a...          1       KR
# 82698   stay here for few hours and transit to danang,...          1       MY
# 104489                                         ok, good !          1       VN
# 20827   great location,near to night market but avoid ...          1       CN
# 13482   Hotel owner's father is able to speak Mandarin...          1       MY
# 111895  Tôi đã lưu trú ở ks 2 đêm, phòng ks tuy không ...          1       VN
# 88181   Clean, friendly staff, top notch location. The...          1       CA
#
#        language
# 26680        en
# 57281        en
# 64161        vi
# 68969        en
# 107143       en
# 51552        en
# 11180        en
# 110729       en
# 27450        en
# 35975        en
# 104535       en
# 10109        en
# 80840        vi
# 21682        en
# 87350        vi
# 18343        en
# 34544        en
# 52086        vi
# 84170        en
# 114159       en
# 62812        en
# 55890        en
# 104285       vi
# 118611       vi
# 8350         en
# 26257        en
# 99366        en
# 6941         en
# 82818        en
# 3612         en
# 99334        vi
# 35173        en
# 106544       vi
# 71483        en
# 12636        en
# 93174        en
# 18167        en
# 120404       en
# 91846        en
# 5565         vi
# 104808       vi
# 80241        vi
# 97863        en
# 41611        en
# 82698        en
# 104489       en
# 20827        en
# 13482        en
# 111895       vi
# 88181        en

# %%
filtered_hotel.shape
# Out:
# (8, 11)

# %%
filtered_hotel = selection.filtering(
    extracting = 'hotel',
#     province=['Da Nang'],
#     star_rating=[3],
    region=['Central Vietnam'],
#     dis2coast=[0, 0.5],
    seaside=0
)
filtered_hotel.shape
# Out:
# (7, 7)

# %%
def extract_embedding(df: pd.DataFrame,corpus_embedding):
    return corpus_embedding[df.index]

# %%
extracted_embedding = extract_embedding(filtered_hotel,corpus_embeddings)

# %%
len(extracted_embedding)
# Out:
# 7

# %%
sample.index
# Out:
# Index([ 26680,  57281,  64161,  68969, 107143,  51552,  11180, 110729,  27450,
#         35975, 104535,  10109,  80840,  21682,  87350,  18343,  34544,  52086,
#         84170, 114159,  62812,  55890, 104285, 118611,   8350,  26257,  99366,
#          6941,  82818,   3612,  99334,  35173, 106544,  71483,  12636,  93174,
#         18167, 120404,  91846,   5565, 104808,  80241,  97863,  41611,  82698,
#        104489,  20827,  13482, 111895,  88181],
#       dtype='int64')

# %%
len(processed_df[processed_df.index.isin(sample.index)].processed_comment.values)
# Out:
# 50

# %% [markdown]
# # Topic Modeling run

# %%
# %%capture
from stopwordsiso import stopwords
import pandas as pd
import os
import numpy as np
from sentence_transformers import SentenceTransformer
from umap import UMAP
from hdbscan import HDBSCAN
from stopwordsiso import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance, PartOfSpeech
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic import BERTopic

# %%
encoder = SentenceTransformer('sentence-transformers/paraphrase-multilingual-mpnet-base-v2')
stop_word_mul = stopwords(['vi','en'])
umap_model=UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine', random_state=42)
hdbscan_model=HDBSCAN(metric='euclidean', cluster_selection_method='eom', prediction_data=True)
vectorizer_model=CountVectorizer(stop_words=list(stop_word_mul), min_df=2, ngram_range=(1,2))
keybert_model=KeyBERTInspired()
pos_model=PartOfSpeech('en_core_web_sm')
mmr_model=MaximalMarginalRelevance(diversity=0.3)
representation_model={
    'KeyBERT':keybert_model,
    'MMR':mmr_model,
    'POS':pos_model
}

# %%
def run(df: pd.DataFrame,top_n_words=100, **kwargs):
    """
    Topic Modeling with BERTopic process
    """
    ### PROCESSED DF
    file_path = 'database/processed_hotel_reviews.csv'
    if os.path.isfile(file_path):
        processed_df = pd.read_csv(file_path, index_col=0)
    else:    
        processed_df = preprocess(df,type = 'sample')
    docs = processed_df[processed_df.index.isin(df.index)].processed_comment.values.astype('str')
    
    ### EMBEDDINGS
    encoder = SentenceTransformer('sentence-transformers/paraphrase-multilingual-mpnet-base-v2')

    file_path = 'database/corpus_embeddings.npy'
    if os.path.isfile(file_path):
        corpus_embeddings = np.load(file_path)
        extracted_embedding = extract_embedding(df, corpus_embeddings)
    else:
        corpus_embeddings = embedding(docs,encoder, type='sample')
        df = df.reset_index()
        extracted_embedding = extract_embedding(df, corpus_embeddings)
    
    ### Set default values for parameters
    umap_defaults = {
        'n_neighbors': 15,
        'n_components': 5,
        'min_dist': 0.0,
        'metric': 'cosine',
        'random_state': 42
    }
    
    hdbscan_defaults = {
        'metric': 'euclidean',
        'min_cluster_size': 5,
        'min_samples': 1,
        'prediction_data': True
    }
    
    ### Override defaults with any provided kwargs
    umap_params = {**umap_defaults, **kwargs.get('umap_params', {})}
    hdbscan_params = {**hdbscan_defaults, **kwargs.get('hdbscan_params', {})}
    
    ### DIMENSIONALITY REDUCTION:
    umap_model = UMAP(**umap_params)
    
    ### CLUSTERING:
    hdbscan_model = HDBSCAN(**hdbscan_params)

    ### VECTORIZERS:
    stop_word_mul = stopwords(['vi','en'])
    vectorizer_model = CountVectorizer(stop_words=list(stop_word_mul), min_df=2, ngram_range=(1, 2))

    ### c-TF-IDF:
    ctfidf_model = ClassTfidfTransformer()
    
    ### REPRESENTATION:
    keybert_model = KeyBERTInspired()
    pos_model = PartOfSpeech('en_core_web_sm')
    mmr_model = MaximalMarginalRelevance(diversity=0.3)
    representation_model = {
        'KeyBERT': keybert_model,
        'MMR': mmr_model,
        'POS': pos_model
    }
    
    topic_model = BERTopic(
        embedding_model=encoder,
        umap_model=umap_model,
        hdbscan_model=hdbscan_model,
        vectorizer_model=vectorizer_model,
        representation_model=representation_model,
        # hyperparameters
        top_n_words=top_n_words,
        verbose=True
    )
    topics, probs = topic_model.fit_transform(docs, extracted_embedding)
    return topic_model

# %%
topic_model = run(filtered_hotel,top_n_words = 20)
# Out:
# C:\Users\darkn\AppData\Local\Temp\ipykernel_15788\3170188387.py:8: DtypeWarning: Columns (17,18,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   processed_df = pd.read_csv(file_path, index_col=0)

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                               Name  \
# 0     -1      8          -1_night_stayed_window_nt
# 1      0     11         0_bus_ks_service_breakfast
# 2      1     11              1_location_view_đồ_ko
# 3      2      8                 2_phòng_mùi_khá_ăn
# 4      3      7             3_hotel_buffet_sáng_ăn
# 5      4      5  4_friendly staff_plans_wet_giá_cả
#
#                                       Representation  \
# 0  [night, stayed, window, nt, staff, dinner, ama...
# 1  [bus, ks, service, breakfast, price, hotel, ma...
# 2  [location, view, đồ, ko, breakfast, clean, cus...
# 3  [phòng, mùi, khá, ăn, bus, hotel, stay, giá_cả...
# 4  [hotel, buffet, sáng, ăn, khá, view, staff, tầ...
# 5  [friendly staff, plans, wet, giá_cả, customer,...
#
#                                              KeyBERT  \
# 0  [hotel, hotels, visit, trip, nice, staff, reco...
# 1  [hotel hotel, hotel, hotel clean, restaurants,...
# 2  [hotel, friendly staff, restaurants, staff, ni...
# 3  [hotel hotel, hotel, phòng, visit, trip, giúp ...
# 4  [hotel, hotel hotel, hotels, phòng, visit, sta...
# 5  [friendly staff, nice, hotel clean, hotel, đẹp...
#
#                                                  MMR  \
# 0  [night, window, dinner, vietnam, trip, recomme...
# 1  [bus, service, breakfast, price, hotel, clean,...
# 2  [location, view, clean, customer, booked, frie...
# 3  [phòng, bus, hotel, stay, giúp thuê, located, ...
# 4  [hotel, buffet, sáng, view, staff, toilet, hot...
# 5  [friendly staff, plans, wet, customer, hotel c...
#
#                                                  POS  \
# 0  [night, window, staff, close, trip, amazing, b...
# 1  [bus, service, breakfast, price, hotel, market...
# 2  [location, view, breakfast, clean, river, mone...
# 3  [phòng, ăn, bus, hotel, polite, trip, morning,...
# 4  [hotel, khá, view, staff, day, time, hotels, t...
# 5  [friendly staff, plans, wet, customer, staff, ...
#
#                                  Representative_Docs
# 0  [great locationnear to night market but avoid ...
# 1  [tôi đã lưu_trú ở ks 2 đêm phòng ks tuy không ...
# 2  [they give us welcome drink and snack when we ...
# 3  [phục_vụ thân_thiện giá_cả phải_chăng gần thun...
# 4  [henry greeted us and prepared our room he is ...
# 5  [phòng mới đẹp giá_cả hợp_lý, great view great...
